# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0"> Ejericicio 1: Crimenes en la ciudad de Mérida (Ficticio)  </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/policia.jpeg" align="middle" style="width:550px"/></td>
# <td>
#
# La Fiscalía General del Estado informó que al día en promedio en Yucatán se registran ocho robos en sus diferentes modalidades, aunque la mayor parte de ellos, cerca del 80 por ciento, ocurre en Mérida.
#
# En esta ciudad, las zonas de mayor incidencia son el Poniente, Sur y Centro.
#
# Aunque los casos más sonados, de mayor cuantía en cuanto al botín y que han llamado la atención de los medios, se dijo que se han registrado en el Norte.
#
# https://www.yucatan.com.mx/merida/merida-el-blanco-principal-de-los-robos
#
#  <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# <div class="alert alert-success">
#
# Con los datos del archivo "asaltos_yucatan.csv", mostrar en un mapa la ubicación de los delitos en Mérida, de ser posible muestre como _popup_ la categoría.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
#Cargar el archivo datos/asaltos_yucatan.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
data = pd.read_csv('datos/asaltos_yucatan.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
data.head()
# Out:
#    NumInc  Categoria              Descripcion   Ciudad          Direccion  \
# 0       1     asalto  robo objetos personales  Tizimín             Centro
# 1       2     asalto  robo objetos personales   Mérida         Calle 53-F
# 2       3     asalto  robo objetos personales   Mérida   Calle 53 791-803
# 3       4     asalto  robo objetos personales   Mérida   Calle 49 808-796
# 4       5  robo casa     robo casa habitacion   Mérida  Calle 51A 784-780
#
#          lat       long
# 0  21.142586 -88.147633
# 1  21.074071 -89.666229
# 2  21.077830 -89.655865
# 3  21.001845 -89.713986
# 4  21.000559 -89.712173

# %%
mapa = folium.Map(location=[20.9785, -89.6332],zoom_start=9)

# %%
for i, row in data.iterrows():
    folium.Marker([row['lat'], row['long']], 
                  popup=f"Categoria: {row['Categoria']}").add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f2cb392fb0517c7ad3f33b962a1bdd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f2cb392fb0517c7ad3f33b962a1bdd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f2cb392fb0517c7ad3f33b962a1bdd8 = L.map(
#                 &quot;map_6f2cb392fb0517c7ad3f33b962a1bdd8&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00192043c0632c22b679d981a08a2cf5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f2cb392fb0517c7ad3f33b962a1bdd8);
#
#
#             var marker_0044cf60d240283b0c12ff2261712a12 = L.marker(
#                 [21.142586, -88.147633],
#                 {}
#             ).addTo(map_6f2cb392fb0517c7ad3f33b962a1bdd8);
#
#
#         var popup_a11cdbfc0441a83df8f8cc7367aab0e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65e693ac2617f5f8b24776d7d53156c9 = $(`&lt;div id=&quot;html_65e693ac2617f5f8b24776d7d53156c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Categoria: asalto&lt;/div&gt;`)[0];
#                 popup_a11cdbfc0441a83df8f8cc7367aab0e6.setContent(html_65e693ac2617f5f8b24776d7d53156c9);
#
#
#
#         marker_0044cf60d240283b0c12ff2261712a12.bindPopup(popup_a11cdbfc0441a83df8f8cc7367aab0e6)
#         ;
#
#
#
#
#             var marker_242d9c25dca4e38bc6062a21ddf03d91 = L.marker(
#                 [21.074071, -89.666229],
#                 {}
#             ).addTo(map_6f2cb392fb0517c7ad3f33b962a1bdd8);
#
#
#         var popup_c8e20cc7e7741a5a75707a882f3551ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5072f558f94028431c0cd0908d058f2d = $(`&lt;div id=&quot;html_5072f558f94028431c0cd0908d058f2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Categoria: asalto&lt;/div&gt;`)[0];
#                 popup_c8e20cc7e7741a5a75707a882f3551ce.setContent(html_5072f558f94028431c0cd0908d058f2d);
#
#
#
#         marker_242d9c25dca4e38bc6062a21ddf03d91.bindPopup(popup_c8e20cc7e7741a5a75707a882f3551ce)
#         ;
#
#
#
#
#             var marker_1471a86716faeade6e3f7a58e94b2eb3 = L.marker(
#                 [21.07783, -89.655865],
#                 {}
#             ).addTo(map_6f2cb392fb0517c7ad3f33b962a1bdd8);
#
#
#         var popup_a449ea03596845fedb15dae2eb00d484 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f6e6edd6cc1b789241143911a51d5f3 = $(`&lt;div id=&quot;html_9f6e6edd6cc1b789241143911a51d5f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Categoria: asalto&lt;/div&gt;`)[0];
#                 popup_a449ea03596845fedb15dae2eb00d484.setContent(html_9f6e6edd6cc1b789241143911a51d5f3);
#
#
#
#         marker_1471a86716faeade6e3f7a58e94b2eb3.bindPopup(popup_a449ea03596845fedb15dae2eb00d484)
#         ;
#
#
#
#
#             var marker_4196aa13ed2aaf8be333ba0482be7b8e = L.marker(
#                 [21.001845, -89.713986],
#                 {}
#             ).addTo(map_6f2cb392fb0517c7ad3f33b962a1bdd8);
#
#
#         var popup_0c743a6adf0d41cccfb298ebc2815afe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf9b94b3e87bdb9b69d76be50a069d55 = $(`&lt;div id=&quot;html_bf9b94b3e87bdb9b69d76be50a069d55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Categoria: asalto&lt;/div&gt;`)[0];
#                 popup_0c743a6adf0d41cccfb298ebc2815afe.setContent(html_bf9b94b3e87bdb9b69d76be50a069d55);
#
#
#
#         marker_4196aa13ed2aaf8be333ba0482be7b8e.bindPopup(popup_0c743a6adf0d41cccfb298ebc2815afe)
#         ;
#
#
#
#
#             var marker_ee5ade0beb30cf4136c82052d61fffcd = L.marker(
#                 [21.000559, -89.712173],
#                 {}
#             ).addTo(map_6f2cb392fb0517c7ad3f33b962a1bdd8);
#
#
#         var popup_1a05e25bbbced3344f6be58b245d350a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_516f9ede7f803b12aa5d3b145192114a = $(`&lt;div id=&quot;html_516f9ede7f803b12aa5d3b145192114a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Categoria: robo casa&lt;/div&gt;`)[0];
#                 popup_1a05e25bbbced3344f6be58b245d350a.setContent(html_516f9ede7f803b12aa5d3b145192114a);
#
#
#
#         marker_ee5ade0beb30cf4136c82052d61fffcd.bindPopup(popup_1a05e25bbbced3344f6be58b245d350a)
#         ;
#
#
#
#
#             var marker_c66af91f1955bf2c147eefff3603b5bc = L.marker(
#                 [20.998856, -89.7
